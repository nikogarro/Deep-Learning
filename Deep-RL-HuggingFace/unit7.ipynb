# %% [markdown]
# <a href="https://colab.research.google.com/github/nikogarro/Deep-Learning/blob/main/Deep-RL-HuggingFace/unit7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# Clone the repository
# !git clone --depth 1 https://github.com/huggingface/ml-agents/

# %%
# %%capture
# Go inside the repository and install the package
# %cd ml-agents
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents

# %%
# Here, we create training-envs-executables 
# !mkdir ./training-envs-executables
# !mkdir ./training-envs-executables/linux

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL" -O ./training-envs-executables/linux/SoccerTwos.zip && rm -rf /tmp/cookies.txt
# Out:
# --2023-02-13 17:22:45--  https://docs.google.com/uc?export=download&confirm=t&id=1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL
# Resolving docs.google.com (docs.google.com)... 172.217.194.113, 172.217.194.102, 172.217.194.139, ...
# Connecting to docs.google.com (docs.google.com)|172.217.194.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-04-8c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/36pk0f7ffiohplhala9sqh35rari7sfd/1676308950000/09764732090272539193/*/1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL?e=download&uuid=a734f7ad-562d-4a28-b0de-f0a9bd4fef15 [following]
# ...
# --2023-02-13 17:22:45--  https://doc-04-8c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/36pk0f7ffiohplhala9sqh35rari7sfd/1676308950000/09764732090272539193/*/1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL?e=download&uuid=a734f7ad-562d-4a28-b0de-f0a9bd4fef15
# ...

# %%
# %%capture
# !unzip -d ./training-envs-executables/linux/SoccerTwos ./training-envs-executables/linux/SoccerTwos.zip

# %%
# !chmod -R 755 ./training-envs-executables/linux/SoccerTwos

# %%
# !./config/poca/SoccerTwos.yaml

# %% [markdown]
# ./config/poca/SoccerTwos.yaml

# %%
# !mlagents-learn /content/ml-agents/config/poca/SoccerTwos.yaml --env=/content/ml-agents/training-envs-executables/linux/SoccerTwos/SoccerTwos --run-id="SoccerTwos" --no-graphics --force
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 0.29.0.dev0,
#   ml-agents-envs: 0.29.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 1.8.1+cu102
# [INFO] Connected to Unity environment with package version 2.3.0-exp.3 and communication version 1.5.0
# ...

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !mlagents-push-to-hf  --run-id="SoccerTwos" --local-dir="./results/SoccerTwos" --repo-id="nikogarro/POCA-SoccerTwos" --commit-message="First Version"
# Out:
# SoccerTwos
# nikogarro/POCA-SoccerTwos
# This function will create a model card and upload your SoccerTwos into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# REPO NAME:  POCA-SoccerTwos
# ORGANIZATION:  nikogarro
# /content/hub/POCA-SoccerTwos is already a clone of https://huggingface.co/nikogarro/POCA-SoccerTwos. Make sure you pull the latest changes with `repo.git_pull()`.
# Upload file SoccerTwos/SoccerTwos-999776.pt:   0% 32.0k/33.1M [00:00<?, ?B/s]
# Upload file SoccerTwos/SoccerTwos-0.pt:   0% 32.0k/9.04M [00:00<?, ?B/s]
#
# Upload file SoccerTwos.onnx:   1% 32.0k/2.69M [00:00<?, ?B/s]
#
#
# Upload file SoccerTwos/SoccerTwos-1001776.pt:   0% 32.0k/33.1M [00:00<?, ?B/s]
#
#
#
# Upload file SoccerTwos/SoccerTwos-0.onnx:   2% 32.0k/1.68M [00:00<?, ?B/s]
#
#
#
#
# Upload file SoccerTwos/SoccerTwos-999776.onnx:   1% 32.0k/2.69M [00:00<?, ?B/s]
#
#
#
#
#
# ...
